# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'corn.ui'
#
# Created by: PyQt5 UI code generator 5.13.0
#
# WARNING! All changes made in this file will be lost!

from PyQt5 import QtCore,  QtWidgets
from PyQt5.QtGui import QIcon
from PyQt5.QtWidgets import QMessageBox


class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")

        MainWindow.resize(800, 600)
        MainWindow.setStyleSheet("")
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.pushButton_open = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_open.setGeometry(QtCore.QRect(330, 300, 131, 31))
        self.pushButton_open.setStyleSheet(
            "text-align : center;\n"
            "font: 9pt \"等线\";\n"
            "\n"
            "background:#F7D674;border-radius:5px;}QPushButton:hover{background:white;\n"
            "                     background-color : rgb(255, 255, 127);\n"
            "                     font: bold;\n"
            "                     border-color: gray;\n"
            "                     border-width: 2px;\n"
            "                     border-radius: 10px;\n"
            "                     padding: 6px;\n"
            "                     height : 14px;\n"
            "                     border-style: outset;\n"
            "                     font : 14px;}\n"
            "                     QPushButton:pressed\n"
            "                     {text-align : center;\n"
            "                     background-color : light gray;\n"
            "                     font: bold;\n"
            "                     border-color: gray;\n"
            "                     border-width: 2px;\n"
            "                     border-radius: 10px;\n"
            "                     padding: 6px;\n"
            "                     height : 14px;\n"
            "                     border-style: outset;\n"
            "                     font : 14px;")
        self.pushButton_open.setObjectName("pushButton_open")
        self.pushButton_pre = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_pre.setGeometry(QtCore.QRect(330, 450, 131, 31))
        self.pushButton_pre.setStyleSheet(
            "text-align : center;\n"
            "font: 9pt \"等线\";\n"
            "background:#F76677;border-radius:5px;}QPushButton:hover{background:white;\n"
            "                     background-color : rgb(255, 85, 127);\n"
            "                     font: bold;\n"
            "                     border-color: gray;\n"
            "                     border-width: 2px;\n"
            "                     border-radius: 10px;\n"
            "                     padding: 6px;\n"
            "                     height : 14px;\n"
            "                     border-style: outset;\n"
            "                     font : 14px;}\n"
            "                     QPushButton:pressed\n"
            "                     {text-align : center;\n"
            "                     background-color : light gray;\n"
            "                     font: bold;\n"
            "                     border-color: gray;\n"
            "                     border-width: 2px;\n"
            "                     border-radius: 10px;\n"
            "                     padding: 6px;\n"
            "                     height : 14px;\n"
            "                     border-style: outset;\n"
            "                     font : 14px;\n"
            "")
        self.pushButton_pre.setObjectName("pushButton_pre")
        self.label = QtWidgets.QLabel(self.centralwidget)
        self.label.setGeometry(QtCore.QRect(190, 10, 411, 61))
        self.label.setStyleSheet("font: 9pt \"黑体\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(self.centralwidget)
        self.label_2.setGeometry(QtCore.QRect(290, 80, 211, 211))
        self.label_2.setStyleSheet(
            "border-width: 2px;\n"
            "font: 9pt \"等线\";\n"
            "border-style: solid;\n"
            "border-color: rgb(0, 0, 0);\n"
            "background-color: rgb(255, 255, 255);\n"
            "text-align : center;\n"
            "                     background-color : white;\n"
            "                     font: bold;\n"
            "                     border-color: gray;\n"
            "                     border-width: 2px;\n"
            "                     border-radius: 10px;\n"
            "                     padding: 6px;\n"
            "                     height : 14px;\n"
            "                     border-style: outset;\n"
            "                     font : 14px;}\n"
            "                     QPushButton:pressed\n"
            "                     {text-align : center;\n"
            "                     background-color : light gray;\n"
            "                     font: bold;\n"
            "                     border-width: 2px;\n"
            "                     border-radius: 10px;\n"
            "                     padding: 6px;\n"
            "                     height : 14px;\n"
            "                     border-style: outset;\n"
            "                     font : 14px;")
        self.label_2.setObjectName("label_2")
        self.textEdit = QtWidgets.QTextEdit(self.centralwidget)
        self.textEdit.setGeometry(QtCore.QRect(290, 340, 211, 101))
        self.textEdit.setStyleSheet(
            "text-align : center;\n"
            "                     background-color : white;\n"
            "                     font: bold;\n"
            "                     border-color: gray;\n"
            "                     border-width: 2px;\n"
            "                     border-radius: 10px;\n"
            "                     padding: 6px;\n"
            "                     height : 14px;\n"
            "                     border-style: outset;\n"
            "                     font : 14px;}\n"
            "                     QPushButton:pressed\n"
            "                     {text-align : center;\n"
            "                     background-color : light gray;\n"
            "                     font: bold;\n"
            "                     border-color: gray;\n"
            "                     border-width: 2px;\n"
            "                     border-radius: 10px;\n"
            "                     padding: 6px;\n"
            "                     height : 14px;\n"
            "                     border-style: outset;\n"
            "                     font : 14px;")
        self.textEdit.setObjectName("textEdit")
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 800, 26))
        self.menubar.setObjectName("menubar")
        self.menu = QtWidgets.QMenu(self.menubar)
        self.menu.setObjectName("menu")
        self.menu_3 = QtWidgets.QMenu(self.menu)
        self.menu_3.setObjectName("menu_3")
        self.menu_2 = QtWidgets.QMenu(self.menubar)
        self.menu_2.setObjectName("menu_2")
        MainWindow.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)
        self.actionFIDenseNet = QtWidgets.QAction(MainWindow)
        self.actionFIDenseNet.setObjectName("actionFIDenseNet")
        self.actionFIDenseNet.triggered.connect(MainWindow.fidensenet)

        self.actionDenseNet169 = QtWidgets.QAction(MainWindow)
        self.actionDenseNet169.setObjectName("actionDenseNet169")
        self.actionDenseNet169.triggered.connect(MainWindow.densenet169)

        self.actionResNet50 = QtWidgets.QAction(MainWindow)
        self.actionResNet50.setObjectName("actionResNet50")
        self.actionResNet50.triggered.connect(MainWindow.resnet50)

        self.actionMobileNet = QtWidgets.QAction(MainWindow)
        self.actionMobileNet.setObjectName("actionMobileNet")
        self.actionMobileNet.triggered.connect(MainWindow.mobilenet)

        self.action_2 = QtWidgets.QAction(MainWindow)
        self.action_2.setObjectName("action_2")
        self.action_2.triggered.connect(MainWindow.help)
        self.action_3 = QtWidgets.QAction(MainWindow)
        self.action_3.setObjectName("action_3")
        self.action_3.triggered.connect(MainWindow.about)
        self.menu_3.addAction(self.actionFIDenseNet)
        self.menu_3.addAction(self.actionDenseNet169)
        self.menu_3.addAction(self.actionResNet50)
        self.menu_3.addAction(self.actionMobileNet)
        self.menu.addAction(self.menu_3.menuAction())
        self.menu_2.addAction(self.action_2)
        self.menu_2.addAction(self.action_3)
        self.menubar.addAction(self.menu.menuAction())
        self.menubar.addAction(self.menu_2.menuAction())
        self.retranslateUi(MainWindow)
        self.pushButton_open.clicked.connect(MainWindow.imageopen)
        self.pushButton_pre.clicked.connect(MainWindow.pre)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

    def fidensenet(self):
        QMessageBox.setWindowIcon(self, QIcon('./images/c4.png'))
        QMessageBox.about(self, "FI-DenseNet", "\n当前卷积神经网络架构为：FI-DenseNet\n平均识别率为：98.97%")
        self.setWindowTitle("农业病害识别系统 FI-DenseNet")

    def densenet169(self):
        QMessageBox.setWindowIcon(self, QIcon('./images/c1.png'))
        QMessageBox.about(self, "DenseNet169", "\n当前卷积神经网络架构为：DenseNet169\n平均识别率为：98.23%")
        self.setWindowTitle("农业病害识别系统 DenseNet169")

    def resnet50(self):
        QMessageBox.setWindowIcon(self, QIcon('./images/c3.png'))
        QMessageBox.about(self, "ResNet50", "\n当前卷积神经网络架构为：ResNet50\n平均识别率为：97.46%")
        self.setWindowTitle("农业病害识别系统 ResNet50")

    def mobilenet(self):
        QMessageBox.setWindowIcon(self, QIcon('./images/c5.png'))
        QMessageBox.about(self, "MobileNet", "\n当前卷积神经网络架构为：MobileNet\n平均识别率为：96.80%")
        self.setWindowTitle("农业病害识别系统 MobileNet")

    def help(self):
        QMessageBox.setWindowIcon(self, QIcon('./images/c2.png'))
        QMessageBox.about(self, "帮助",
                          "这是一个基于深度学习的农业病害识别系统，有四种卷积架构模型可供选择，可识别38种农业病害，平均识别率最高可达98.97%！\n如有疑问请发送邮件至liu_ao_yu@163.com")

    def about(self):
        QMessageBox.setWindowIcon(self, QIcon('./images/ahau.jpg'))
        QMessageBox.about(self, "关于作者", "安徽农业大学\n刘翱宇、朱小宁")

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        self.setWindowIcon(QIcon('./images/c4.png'))
        MainWindow.setWindowTitle(_translate("MainWindow", "农业病害识别系统"))
        self.pushButton_open.setText(_translate("MainWindow", "从本地导入图像"))
        self.pushButton_pre.setText(_translate("MainWindow", "开始预测"))
        self.label.setText(
            _translate(
                "MainWindow",
                "<html><head/><body><p align=\"center\"><span style=\" font-size:28pt; font-weight:600; color:#006400;\">农业病害识别系统</span></p></body></html>"
            ))
        op1 = QtWidgets.QGraphicsOpacityEffect()
        # 设置透明度的值，0.0到1.0，最小值0是透明，1是不透明
        op1.setOpacity(0.7)
        op2 = QtWidgets.QGraphicsOpacityEffect()
        # 设置透明度的值，0.0到1.0，最小值0是透明，1是不透明
        op2.setOpacity(0.7)
        op3 = QtWidgets.QGraphicsOpacityEffect()
        # 设置透明度的值，0.0到1.0，最小值0是透明，1是不透明
        op3.setOpacity(0.9)
        op4 = QtWidgets.QGraphicsOpacityEffect()
        # 设置透明度的值，0.0到1.0，最小值0是透明，1是不透明
        op4.setOpacity(0.9)
        self.label_2.setGraphicsEffect(op1)
        self.textEdit.setGraphicsEffect(op2)
        self.pushButton_open.setGraphicsEffect(op3)
        self.pushButton_pre.setGraphicsEffect(op4)
        self.label_2.setText(
            _translate(
                "MainWindow",
                "<html><head/><body><p align=\"center\"><span style=\" font-size:12pt;\">图像</span></p></body></html>"
            ))
        self.menu.setTitle(_translate("MainWindow", "菜单"))
        self.menu_3.setTitle(_translate("MainWindow", "选择模型\n" ""))
        self.menu_2.setTitle(_translate("MainWindow", "帮助"))
        self.actionFIDenseNet.setText(_translate("MainWindow", "FI-DenseNet"))
        self.actionDenseNet169.setText(_translate("MainWindow", "DenseNet169"))
        self.actionResNet50.setText(_translate("MainWindow", "ResNet50"))
        self.actionMobileNet.setText(_translate("MainWindow", "MobileNet"))
        self.action_2.setText(_translate("MainWindow", "说明\n" ""))
        self.action_3.setText(_translate("MainWindow", "关于作者\n" ""))
